# %%
import pandas as pd
import requests
import pandas as pd
import re
import json
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings("ignore")

# %%
URL1 = "https://www.bitcoinmarketjournal.com/ico-regulations/"
URL2="https://www.iexpats.com/cryptocurrency-tax-and-rules-by-country/"
URL3="https://icoda.io/list-of-all-crypto-exchanges/"
URL4="https://cbdctracker.org/"
url="https://cbdctracker.org/api/currencies"

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

ptrn=re.compile("(<td>)|(</td>)")


changes={
"Yes":"Taxable",
"No":"Non-Taxable",
"–":"Banned",
"Allowed":"Allowed",
"Allowed, but heavily regulated":"Allowed but regulated",
"Allowed, but regulated":"Allowed but regulated",
"Allowed, but subject to future regulations":"Allowed but regulations underway",
"Allowed, but subject to future regulations":"Allowed but regulations underway",
"Allowed, but subject to future \xa0 regulations":"Allowed but regulations underway",
"Allowed/Regulated":"Allowed but regulated",
"Allowed/See note":"Allowed",
"Allowed/See Notes":"Allowed",
"Allowed/Subject to future regulations":"Allowed but regulations underway",
"Banned":"Banned", 
"Legal":"Allowed"}



i=1
c=0
lst=[]
lst1=[]
lst2=[]

def parsing(url,tag,headers):
	page = requests.get(url,verify=False,headers=headers)
	soup = BeautifulSoup(page.content, "html.parser")
	results=soup.find_all(tag)
	return results

results=parsing(URL1,"td",headers)
results1=parsing(URL2,"tr",headers)
results2=parsing(URL3,"tbody",headers)


page = requests.get(url,verify=False,headers=headers)
data=json.loads(page.content)


for values in results:
	if ((i%3==0) or (i<3)):
		pass
	else:
		if c==0:
			prev=(values.text)
			c=1
		else:
			lst.append([prev,values.text])
			c=0
	i=i+1


for values in results1:
	val=values.find_all("td")
	if len(val)!=0:
		lst1.append([re.sub(ptrn,"",str(val[0])),re.sub(ptrn,"",str(val[3]))])

for values in results2:
	val_p=values.find_all("tr")

	for ind in range(0,len(val_p)):
		dd={}
		for i in val_p[ind]:
			if i.find('span'):
				if i.find("p"):
					dd[i.find("span").text]=i.find("p").text
				else:
					dd[i.find("span").text]=''
			else:
				dd['Exchange']=i.find("p").text
				if i.find("p"):
					dd['Exchange']=i.find("p").text
				else:
					dd['Exchange']=''
				
		lst2.append(dd)



df_bitcoin=pd.DataFrame(lst,columns=['Country','Status'])
df_iex=pd.DataFrame(lst1,columns=['Country','Status'])
df_icod=pd.DataFrame.from_dict(lst2,orient='columns')
df_cdbc=pd.DataFrame.from_dict(data,orient='columns')

df_cdbc=df_cdbc[['country','status']]
df_iex['Status']=df_iex['Status'].apply(lambda x: changes[x])
df_bitcoin['Status']=df_bitcoin['Status'].apply(lambda x: changes[x])

# %%
df_icod=df_icod[df_icod['Country']!='No Data']

# %%
df_icod=df_icod[~(df_icod['Launched'].isin(['','No Data']))]

# %%
for con in df_icod['Country'].unique():
    min_val=df_icod[df_icod['Country']==con]['Launched'].min()
    lst3.append([con,df_icod[(df_icod['Country']==con)&(df_icod['Launched']==min_val)]['Type'].values[0]])
# Out:
# Singapore Centralized
# Australia Centralized
# Seychelles Centralized
# United States Centralized
# South Korea Centralized
# Canada Centralized
# Malta No Data
# Mexico Centralized
# Sweden Centralized
# United Kingdom Centralized
# Netherlands Centralized
# South Africa Centralized
# Russia Centralized
# Switzerland Decentralized
# British Virgin Islands Centralized
# Hong Kong Centralized
# Saint Kitts and Nevis Centralized
# Saint Vincent and the Grenadines No Data
# Cayman Islands Centralized
# China Centralized
# Jersey Centralized
# Uganda Centralized
# Estonia Centralized
# Israel Centralized
# Japan Centralized
# Nigeria Centralized
# India Centralized
# Turkey Centralized
# Poland Centralized
# Bahamas Centralized
# Brasil Centralized
# Croatia Centralized
# Thailand Centralized
# Taiwan Centralized
# Austria Centralized
# Macau Centralized
# Indonesia Centralized
# Ukraine Centralized
# Liechtenstein Decentralized
# Romania Centralized
# Brazil Centralized
# Lithuania Centralized
# United Arab Emirates Centralized
# Chile No Data
# Argentina Centralized
# Philippines Centralized
# Isle of Man Centralized
# Gibraltar Centralized
# Cyprus Centralized
# Azerbaijan Centralized
# Italy Centralized
# Slovakia Centralized
# Samoa Decentralized
# Belize Centralized
# Antigua and Barbuda Centralized
# Finland Decentralized
# Vietnam Centralized
# Mongolia Centralized
# Panama Decentralized
# Malaysia Centralized
# Iceland Centralized
# Saint Vincent and Grenadines Centralized
# France Centralized
# Belarus Centralized
# Germany Decentralized
# Vanuatu Centralized
# Bahrain Centralized
# British Virgin Island Decentralized
# Ireland Centralized

# %%
df_icod.groupby('Country')['Launched']

# %%
df_icod=df_icod[~(df_icod['Launched']=='No Data')]

for con in df_icod['Country'].unique():
	df_icod['Country']==con

df_bitcoin.to_excel("bitcoinmarketjournal.xlsx",index=False)
df_iex.to_excel("iexpats.xlsx",index=False)
df_icod.to_excel("icoda.xlsx",index=False)
df_cdbc.to_excel("cbdctracker.xlsx",index=False)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# %%
URL5="https://en.wikipedia.org/wiki/Legality_of_cryptocurrency_by_country_or_territory#Detail_by_country_or_territory"

# %%
def parsing(url,tag,headers):
	page = requests.get(url,verify=False,headers=headers)
	soup = BeautifulSoup(page.content, "html.parser")
	results=soup.find_all(tag)
	return results

# %%
results3=parsing(URL5,"td",headers)

# %%
results3
# Out:
# [<td class="mbox-image"><img alt="" data-file-height="620" data-file-width="620" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1d/Information_icon4.svg/20px-Information_icon4.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1d/Information_icon4.svg/30px-Information_icon4.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1d/Information_icon4.svg/40px-Information_icon4.svg.png 2x" width="20"/></td>,
#  <td class="mbox-text" style="width: auto;"><div class="mbox-text-span">This list is <a href="/wiki/Wikipedia:WikiProject_Lists#Incomplete_lists" title="Wikipedia:WikiProject Lists">incomplete</a>; you can help by <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Legality_of_cryptocurrency_by_country_or_territory&amp;action=edit">adding missing items</a>.  <span class="date-container"><i>(<span class="date">August 2020</span>)</i></span></div></td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="540" data-file-width="810" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b7/Flag_of_Europe.svg/23px-Flag_of_Europe.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b7/Flag_of_Europe.svg/35px-Flag_of_Europe.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b7/Flag_of_Europe.svg/45px-Flag_of_Europe.svg.png 2x" width="23"/> </span><a href="/wiki/European_Union" title="European Union">European Union</a><span class="anchor" id="European_Union"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>The European Union has passed no specific legislation relative to the status of bitcoin as a currency, but has stated that VAT/GST is not applicable to the conversion between traditional (fiat) currency and bitcoin.
#  </p><p>VAT/GST and other taxes (such as income tax) still apply to transactions made using bitcoins for goods and services. <sup class="reference" id="cite_ref-regulation_3-0"><a href="#cite_note-regulation-3">[3]</a></sup><sup class="reference nowrap"><span title="Page: European Union">: European Union </span></sup>
#  </p><p>In October 2015, the Court of Justice of the European Union ruled that "The exchange of traditional currencies for units of the 'bitcoin' virtual currency is exempt from VAT" and that "Member States must exempt, inter alia, transactions relating to 'currency, bank notes and coins used as <a href="/wiki/Legal_tender" title="Legal tender">legal tender</a><span style="padding-right:.15em;">'</span>", making bitcoin a currency as opposed to being a commodity.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup><sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup> According to judges, the tax should not be charged because bitcoins should be treated as a means of payment.<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup>
#  </p><p>According to the <a href="/wiki/European_Central_Bank" title="European Central Bank">European Central Bank</a>, traditional financial sector regulation is not applicable to bitcoin because it does not involve traditional financial actors.<sup class="reference" id="cite_ref-ECB_7-0"><a href="#cite_note-ECB-7">[7]</a></sup><sup class="reference nowrap"><span title="Page / location: 5">: 5 </span></sup> Others in the EU have stated, however, that existing rules can be extended to include bitcoin and bitcoin companies.<sup class="reference" id="cite_ref-EUPARANNEX_8-0"><a href="#cite_note-EUPARANNEX-8">[8]</a></sup>
#  </p><p>The European Central Bank classifies bitcoin as a convertible decentralized virtual currency.<sup class="reference" id="cite_ref-ECB_7-1"><a href="#cite_note-ECB-7">[7]</a></sup><sup class="reference nowrap"><span title="Page / location: 6">: 6 </span></sup> In July 2014 the <a href="/wiki/European_Banking_Authority" title="European Banking Authority">European Banking Authority</a> advised European banks not to deal in virtual currencies such as bitcoin until a regulatory regime was in place.<sup class="reference" id="cite_ref-EBA_9-0"><a href="#cite_note-EBA-9">[9]</a></sup>
#  </p><p>In 2016 the European Parliament's proposal to set up a taskforce to monitor virtual currencies to combat money laundering and terrorism, passed by 542 votes to 51, with 11 abstentions, has been sent to the European Commission for consideration.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
#  </p><p>In January 2022, <a class="new" href="/w/index.php?title=Erik_Thed%C3%A9en&amp;action=edit&amp;redlink=1" title="Erik Thedéen (page does not exist)">Erik Thedéen</a><span class="noprint" style="font-size:85%; font-style: normal;"> [<a class="extiw" href="https://sv.wikipedia.org/wiki/Erik_Thed%C3%A9en" title="sv:Erik Thedéen">sv</a>]</span>, vice-chair of the <a href="/wiki/European_Securities_and_Markets_Authority" title="European Securities and Markets Authority">European Securities and Markets Authority</a>, called for an <a href="/wiki/European_Union" title="European Union">EU</a> ban on <a href="/wiki/Proof_of_work" title="Proof of work">proof of work</a> crypto-mining to favor the <a href="/wiki/Proof_of_stake" title="Proof of stake">proof of stake</a> model and fight <a href="/wiki/Climate_change" title="Climate change">climate change</a>;<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup>
#  </p>
#  </td>,
#  <td><a class="mw-redirect" href="/wiki/G8_(forum)" title="G8 (forum)">G7</a>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>In 2013 the <a class="mw-redirect" href="/wiki/G7" title="G7">G7</a>'s <a href="/wiki/Financial_Action_Task_Force" title="Financial Action Task Force">Financial Action Task Force</a> issued the following statement in guidelines which may be applicable to companies involved in transmitting bitcoin and other currencies, "Internet-based <a class="mw-redirect" href="/wiki/Payment_services" title="Payment services">payment services</a> that allow third party funding from anonymous sources may face an increased risk of [money laundering/terrorist financing]." They concluded that this may "pose challenges to countries in [anti-money laundering/counter terrorist financing] regulation and supervision".<sup class="reference" id="cite_ref-fatf_12-0"><a href="#cite_note-fatf-12">[12]</a></sup>
#  </p>
#  </td>,
#  <td class="mbox-image"><div style="width:52px"><a class="image" href="/wiki/File:Wiki_letter_w_cropped.svg"><img alt="[icon]" data-file-height="31" data-file-width="44" decoding="async" height="31" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/44px-Wiki_letter_w_cropped.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/66px-Wiki_letter_w_cropped.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/88px-Wiki_letter_w_cropped.svg.png 2x" width="44"/></a></div></td>,
#  <td class="mbox-text"><div class="mbox-text-span">This section <b>needs expansion</b>. You can help by <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Legality_of_cryptocurrency_by_country_or_territory&amp;action=edit&amp;section=">adding to it</a>.<span class="hide-when-compact"> Relevant discussion may be found on the <a href="/wiki/Talk:Legality_of_cryptocurrency_by_country_or_territory#Complete_list_of_missing_countries" title="Talk:Legality of cryptocurrency by country or territory">talk page</a>.</span> <span class="date-container"><i>(<span class="date">April 2017</span>)</i></span></div></td>,
#  <td class="navbox-list-with-group navbox-list navbox-odd hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">
#  <ul><li><a href="#Algeria">Algeria</a></li>
#  <li><a href="#Argentina">Argentina</a></li>
#  <li><a href="#Australia">Australia</a></li>
#  <li><a href="#Austria">Austria</a></li>
#  <li><a href="#Bangladesh">Bangladesh</a></li>
#  <li><a href="#Belarus">Belarus</a></li>
#  <li><a href="#Belgium">Belgium</a></li>
#  <li><a href="#Bolivia">Bolivia</a></li>
#  <li><a href="#Bosnia_and_Herzegovina">Bosnia and Herzegovina</a></li>
#  <li><a href="#Brazil">Brazil</a></li>
#  <li><a href="#Bulgaria">Bulgaria</a></li>
#  <li><a href="#Cambodia">Cambodia</a></li>
#  <li><a href="#Canada">Canada</a></li>
#  <li><a href="#Chile">Chile</a></li>
#  <li><a href="#China">China</a> (<a href="#Hong_Kong">Hong Kong SAR</a>)</li>
#  <li><a href="#Colombia">Colombia</a></li>
#  <li><a href="#Costa_Rica">Costa Rica</a></li>
#  <li><a href="#Croatia">Croatia</a></li>
#  <li><a href="#Cyprus">Cyprus</a></li>
#  <li><a href="#Czech_Republic">Czech Republic</a></li></ul>
#  </div></td>,
#  <td class="navbox-list-with-group navbox-list navbox-even hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">
#  <ul><li><a href
ria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/45px-Flag_of_Algeria.svg.png 2x" width="23"/> </span><a href="/wiki/Algeria" title="Algeria">Algeria</a><span class="anchor" id="Algeria"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:X_mark.svg"><img alt="X mark.svg" data-file-height="600" data-file-width="525" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/15px-X_mark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/23px-X_mark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/30px-X_mark.svg.png 2x" width="15"/></a> Illegal
#  <hr/>
#  <p>According to the "Journal Officiel" (28 December 2017):
#  </p><p>Art. 117. — The purchase, sale, use, and holding of so-called virtual currency is prohibited. Virtual currency is that used by internet users via the web. It is characterized by the absence of physical support such as coins, notes, payments by cheque or credit card. Any breach of this provision is punishable in accordance with the laws and regulations in force.<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup><sup class="reference" id="cite_ref-RCAWJune2018LOC_14-0"><a href="#cite_note-RCAWJune2018LOC-14">[14]</a></sup><sup class="reference nowrap"><span title="Page / location: 82">: 82 </span></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/23px-Flag_of_Egypt.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/35px-Flag_of_Egypt.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/45px-Flag_of_Egypt.svg.png 2x" width="23"/> </span><a href="/wiki/Egypt" title="Egypt">Egypt</a><span class="anchor" id="Egypt"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:X_mark.svg"><img alt="X mark.svg" data-file-height="600" data-file-width="525" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/15px-X_mark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/23px-X_mark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/30px-X_mark.svg.png 2x" width="15"/></a> Illegal
#  <hr/>
#  <p>"Egypt's Dar al-Ifta, the primary Islamic legislator in Egypt, has issued a religious decree classifying commercial transactions in bitcoin as haram (prohibited under Islamic law)."<sup class="reference" id="cite_ref-RCAWJune2018LOC_14-1"><a href="#cite_note-RCAWJune2018LOC-14">[14]</a></sup><sup class="reference nowrap"><span title="Page: 82">: 82 </span></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Morocco.svg/23px-Flag_of_Morocco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Morocco.svg/35px-Flag_of_Morocco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Morocco.svg/45px-Flag_of_Morocco.svg.png 2x" width="23"/> </span><a href="/wiki/Morocco" title="Morocco">Morocco</a><span class="anchor" id="Morocco"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:X_mark.svg"><img alt="X mark.svg" data-file-height="600" data-file-width="525" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/15px-X_mark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/23px-X_mark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/30px-X_mark.svg.png 2x" width="15"/></a> Illegal
#  <hr/>
#  <p>On 20 November 2017 the exchange office issued a public statement in which it declared, "The Office des Changes wishes to inform the general public that the transactions via virtual currencies constitute an infringement of the exchange regulations, liable to penalties and fines provided for by [existing laws] in force."<sup class="reference" id="cite_ref-RCAWJune2018LOC_14-2"><a href="#cite_note-RCAWJune2018LOC-14">[14]</a></sup><sup class="reference nowrap"><span title="Page: 87">: 87 </span></sup>
#  </p><p>The following day, the monetary authorities also reacted in a statement issued jointly by the Ministry of Economy and Finance, Bank Al-Maghrib and the Moroccan Capital Market Authority (AMMC), warning against risks associated with bitcoin, which may be used "for illicit or criminal purposes, including money laundering and terrorist financing".<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup>
#  </p><p>On 19 December 2017, Abdellatif Jouahri, governor of Bank Al-Maghrib, said at a press conference held in Rabat during the last quarterly meeting of the Bank Al-Maghrib's Board of 2017 that bitcoin is not a currency but a "financial asset". He also warned of its dangers and called for a framework to be put in place for consumer protection.<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/23px-Flag_of_Nigeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/35px-Flag_of_Nigeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/46px-Flag_of_Nigeria.svg.png 2x" width="23"/> </span><a href="/wiki/Nigeria" title="Nigeria">Nigeria</a><span class="anchor" id="Nigeria"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal / <a class="image" href="/wiki/File:X_mark.svg"><img alt="X mark.svg" data-file-height="600" data-file-width="525" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/15px-X_mark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/23px-X_mark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/30px-X_mark.svg.png 2x" width="15"/></a> Banking ban
#  <hr/>
#  <p>As of 17 January 2017, The Central Bank of Nigeria (CBN) has passed a circular to inform all Nigerian banks that bank transactions in bitcoin and other virtual currencies have been banned in Nigeria.<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup>
#  </p><p>Later on, a committee was set up by the Central Bank of Nigeria (CBN) and the Nigeria Deposit Insurance Corporation (NDIC) to look into the possibility of the country adopting the technology driving bitcoin and other digital currencies – blockchain. The committee has submitted its report but "several sub-committees are still working on the issue" according to the Director, Banking &amp; Payments System Department at CBN, Mr. ‘Dipo Fatokun.<sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup>
#  </p><p>On 5 February 2021, The <a href="/wiki/Central_Bank_of_Nigeria" title="Central Bank of Nigeria">Central Bank of Nigeria</a> issued a circular informing financial institutions in Nigeria that sequel to their circular in January 2017, dealing in cryptocurrency or facilitating payment for same remains prohibited and would attract a stiff penalty.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/Flag_of_Tanzania.svg/23px-Flag_of_Tanzania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/Flag_of_Tanzania.svg/35px-Flag_of_Tanzania.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/38/Flag_of_Tanzania.svg/45px-Flag_of_Tanzania.svg.png 2x" width="23"/> </span><a href="/wiki/Tanzania" title="Tanzania">Tanzania</a><span class="anchor" id="Tanzania"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal / Use discouraged by central bank
#  <hr/>
#  <p>While not officially banned, the <a href="/wiki/Bank_of_Tanzania" title="Bank of Tanzania">Bank of Tanzania</a> advises not to use cryptocurrency, stressing that the <a href="/wiki/Tanzanian_shilling" title="Tanzanian shilling">Tanzanian shilling</a> is the only acceptable <a href="/wiki/Legal_tender" title="Legal tender">legal tender</a>.<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup><sup class="reference" id="cite_ref-21"><a href="#cite_note-21">[21]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Mauritius.svg/23px-Flag_of_Mauritius.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Mauritius.svg/35px-Flag_of_Mauritius.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Mauritius.svg/45px-Flag_of_Mauritius.svg.png 2x" width="23"/> </span><a href="/wiki/Mauritius" title="Mauritius">Mauritius</a><span class="anchor" id="Mauritius"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>The Financial Services Commission of Mauritius considers cryptocurrencies to be regulated as a Digital Asset under the Financial Services Act 2007, and while it cautions investors they are not protected by any statutory compensation agreements, they are legal.<sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Angola.svg/23px-Flag_of_Angola.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Angola.svg/35px-Flag_of_Angola.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Angola.svg/45px-Flag_of_Angola.svg.png 2x" width="23"/> </span><a href="/wiki/Angola" title="Angola">Angola</a><span class="anchor" id="Angola"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>While government officials have advised against the use of bitcoin, there is no legislation against it and it remains fully legal.<sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[23]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="267" data-file-width="400" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/af/Flag_of_South_Africa.svg/23px-Flag_of_South_Africa.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/af/Flag_of_South_Africa.svg/35px-Flag_of_South_Africa.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/af/Flag_of_South_Africa.svg/45px-Flag_of_South_Africa.svg.png 2x" width="23"/> </span><a href="/wiki/South_Africa" title="South Africa">South Africa</a><span class="anchor" id="South_Africa"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>In December 2014 the Reserve Bank of South Africa issued a position paper on virtual currencies whereby it declared that virtual currency had "no legal status or regulatory framework".<sup class="reference" id="cite_ref-24"><a href="#cite_note-24">[24]</a></sup> The South African Revenue Service classified bitcoin as an intangible asset.<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[25]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Namibia.svg/23px-Flag_of_Namibia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Namibia.svg/35px-Flag_of_Namibia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Namibia.svg/45px-Flag_of_Namibia.svg.png 2x" width="23"/> </span><a href="/wiki/Namibia" title="Namibia">Namibia</a><span class="anchor" id="Namibia"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal / <a class="image" href="/wiki/File:X_mark.svg"><img alt="X mark.svg" data-file-height="600" data-file-width="525" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/15px-X_mark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/23px-X_mark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/30px-X_mark.svg.png 2x" width="15"/></a> Banking ban
#  <hr/>
#  <p>In September 2017 the Bank of Namibia issued a position paper on virtual currencies entitled<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[26]</a></sup> wherein it declared cryptocurrency exchanges are not allowed and cryptocurrency cannot be accepted as payment for goods and services.
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="630" data-file-width="1260" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Flag_of_Zimbabwe.svg/23px-Flag_of_Zimbabwe.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Flag_of_Zimbabwe.svg/35px-Flag_of_Zimbabwe.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Flag_of_Zimbabwe.svg/46px-Flag_of_Zimbabwe.svg.png 2x" width="23"/> </span><a href="/wiki/Zimbabwe" title="Zimbabwe">Zimbabwe</a><span class="anchor" id="Zimbabwe"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Blue_question_mark_(italic).svg"><img alt="Blue question mark (italic).svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Blue_question_mark_%28italic%29.svg/15px-Blue_question_mark_%28italic%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Blue_question_mark_%28italic%29.svg/23px-Blue_question_mark_%28italic%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Blue_question_mark_%28italic%29.svg/30px-Blue_question_mark_%28italic%29.svg.png 2x" width="15"/></a> Unknown
#  <hr/>
#  <p>The Reserve Bank Of Zimbabwe has banned the banking use of crypto currency, however the High Court Order lifted the ban. The Reserve Bank have filed a notice of
#  objection with the Court. However, no source indicating a resolution of the matter was located.<sup class="reference" id="cite_ref-RCAWNovember2021LOC_27-0"><a href="#cite_note-RCAWNovember2021LOC-27">[27]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/23px-Flag_of_Canada_%28Pantone%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/35px-Flag_of_Canada_%28Pantone%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/46px-Flag_of_Canada_%28Pantone%29.svg.png 2x" width="23"/> </span><a href="/wiki/Canada" title="Canada">Canada</a><span class="anchor" id="Canada"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal / <a class="image" href="/wiki/File:X_mark.svg"><img alt="X mark.svg" data-file-height="600" data-file-width="525" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/15px-X_mark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/23px-X_mark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/X_mark.svg/30px-X_mark.svg.png 2x" width="15"/></a> Banking ban
#  <hr/>
#  <p>Companies dealing in virtual currencies must register with the Financial Transactions and Reports Analysis Centre of Canada (Fintrac), implement compliance programs, keep the required records, report suspicious or terrorist-related transactions, and determine if any of their customers are "politically exposed persons."
#  </p><p>The law applies to non-Canadian virtual currency exchanges if they have Canadian customers. Banks may not open or maintain accounts or have a correspondent banking relationship with companies dealing in virtual currencies if that company is not registered with Fintrac.<sup class="noprint Inline-Template" style="margin-left:0.1em; white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Please_clarify" title="Wikipedia:Please clarify"><span title="The text near this tag may need clarification or removal of jargon. (October 2021)">clarification needed</span></a></i>]</sup>
#  </p><p>Dealers in digital currency are regulated as money services businesses.<sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[28]</a></sup>
#  </p><p>The <span title="French-language text"><span lang="fr" style="font-style: normal;">Autorité des Marchés Financiers</span></span>, the financial regulator in the province of <a href="/wiki/Quebec" title="Quebec">Quebec</a>, has declared that some bitcoin related business models, including exchanges and ATMs, are regulated under its current MSB Act.<sup class="reference" id="cite_ref-29"><a href="#cite_note-29">[29]</a></sup>
#  </p><p>As of April 2018, the Bank of Montreal (BMO) announced that it would ban its credit and debit card customers from participating in cryptocurrency purchases with their cards.<sup class="reference" id="cite_ref-30"><a href="#cite_note-30">[30]</a></sup> This is following another banking ban in Canada from Toronto Dominion (TD).<sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/> </span><a href="/wiki/United_States" title="United States">United States</a><span class="anchor" id="United_States"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>The <a href="/wiki/United_States_Department_of_the_Treasury" title="United States Department of the Treasury">U.S. Treasury</a> classified bitcoin as a convertible decentralized virtual currency in 2013.<sup class="reference" id="cite_ref-JSC_32-0"><a href="#cite_note-JSC-32">[32]</a></sup>
#  The Commodity Futures Trading Commission, CFTC, classified bitcoin as a commodity in September 2015. Per the <a href="/wiki/Internal_Revenue_Service" title="Internal Revenue Service">Internal Revenue Service</a> (IRS), bitcoin is taxed as a property.<sup class="reference" id="cite_ref-33"><a href="#cite_note-33">[33]</a></sup>
#  </p><p>Bitcoin was mentioned<sup class="noprint Inline-Template" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Please_clarify" title="Wikipedia:Please clarify"><span title="Please clarify the preceding statement or statements with a good explanation from a reliable source. (October 2021)">how?</span></a></i>]</sup> in a <a class="mw-redirect" href="/wiki/U.S._Supreme_Court" title="U.S. Supreme Court">U.S. Supreme Court</a> opinion (in the case of <i>Wisconsin Central Ltd. v. United States</i>) regarding the changing definition of money on 21 June 2018.<sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup>
#  </p><p>If money services businesses, including cryptocurrency exchanges, money transmitters, and anonymizing services (known as "mixers" or "tumblers") do a substantial amount of business in the U.S., according to <a class="mw-redirect" href="/wiki/FinCEN" title="FinCEN">FinCEN</a> director Kenneth Blanco in 2018, they are required to:<sup class="reference" id="cite_ref-fincen20180809_35-0"><a href="#cite_note-fincen20180809-35">[35]</a></sup>
#  </p>
#  <ul><li>register with the U.S.FinCEN as a money services business</li>
#  <li>design and enforce an anti-money laundering (AML) program, and</li>
#  <li>keep appropriate records and make reports to FinCEN, including Suspicious Activity Reports (SARs) and Currency Transaction Reports (CTRs)</li></ul>
#  <p>As of August 2018<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Legality_of_cryptocurrency_by_country_or_territory&amp;action=edit">[update]</a></sup>, U.S. FinCEN had been receiving more than 1,500 SARs per month involving cryptocurrencies.<sup class="reference" id="cite_ref-fincen20180809_35-1"><a href="#cite_note-fincen20180809-35">[35]</a></sup>
#  Seventeen other countries have similar AML requirements.<sup class="reference" id="cite_ref-RCAWJune2018LOC_14-3"><a href="#cite_note-RCAWJune2018LOC-14">[14]</a></sup>
#  </p><p>In September 2016, a federal judge ruled that "Bitcoins are funds within the plain meaning of that term".<sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[36]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="560" data-file-width="980" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Mexico.svg/23px-Flag_of_Mexico.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Mexico.svg/35px-Flag_of_Mexico.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Mexico.svg/46px-Flag_of_Mexico.svg.png 2x" width="23"/> </span><a href="/wiki/Mexico" title="Mexico">Mexico</a><span class="anchor" id="Mexico"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>Bitcoin was legal in Mexico as of 2017, with plans to regulate it as a virtual asset by the FinTech Law.<sup class="reference" id="cite_ref-elfinanciero20190322_37-0"><a href="#cite_note-elfinanciero20190322-37">[37]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Costa_Rica.svg/23px-Flag_of_Costa_Rica.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Costa_Rica.svg/35px-Flag_of_Costa_Rica.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Costa_Rica.svg/46px-Flag_of_Costa_Rica.svg.png 2x" width="23"/> </span><a href="/wiki/Costa_Rica" title="Costa Rica">Costa Rica</a><span class="anchor" id="Costa_Rica"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Not considered currency
#  <hr/>
#  <p>In October 2017, the <a href="/wiki/Central_Bank_of_Costa_Rica" title="Central Bank of Costa Rica">Central Bank of Costa Rica</a> issued a statement that Bitcoin and cryptocurrencies are not considered currencies, are not backed by law, and cannot be traded on Costa Rica's national payment system. The Central Bank emphasized that anyone who used cryptocurrency did so at their own risk.<sup class="reference" id="cite_ref-38"><a href="#cite_note-38">[38]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="567" data-file-width="1005" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_El_Salvador.svg/23px-Flag_of_El_Salvador.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_El_Salvador.svg/35px-Flag_of_El_Salvador.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_El_Salvador.svg/46px-Flag_of_El_Salvador.svg.png 2x" width="23"/> </span><a href="/wiki/El_Salvador" title="El Salvador">El Salvador</a><span class="anchor" id="El_Salvador"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>Bitcoin was made <a href="/wiki/Legal_tender" title="Legal tender">legal tender</a> in the country through the "<a href="/wiki/Bitcoin_Law" title="Bitcoin Law">Bitcoin Law</a>", which was passed on 8 June 2021,<sup class="reference" id="cite_ref-btcasamblea_39-0"><a href="#cite_note-btcasamblea-39">[39]</a></sup><sup class="reference" id="cite_ref-btcelsalvador20210608_40-0"><a href="#cite_note-btcelsalvador20210608-40">[40]</a></sup> and took effect on 7 September 2021.<sup class="reference" id="cite_ref-wsj20210907_41-0"><a href="#cite_note-wsj20210907-41">[41]</a></sup><sup class="reference" id="cite_ref-cnbc20210907_42-0"><a href="#cite_note-cnbc20210907-42">[42]</a></sup>
#  </p><p>One month on, more Salvadorans have bitcoin wallets than traditional bank accounts, and the most popular bitcoin wallet—the <a href="/wiki/Government_of_El_Salvador" title="Government of El Salvador">government's</a> officially-sponsored Chivo wallet—had been downloaded by three million people, approaching 46 percent of the population.<sup class="reference" id="cite_ref-forbes20211006_43-0"><a href="#cite_note-forbes20211006-43">[43]</a></sup> However, only 12 percent of Salvadoran consumers have used the cryptocurrency, and 93 percent of companies surveyed reported receiving no payments in bitcoin during the first month.<sup class="reference" id="cite_ref-nbc20211007_44-0"><a href="#cite_note-nbc20211007-44">[44]</a></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Nicaragua.svg/23px-Flag_of_Nicaragua.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Nicaragua.svg/35px-Flag_of_Nicaragua.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Nicaragua.svg/46px-Flag_of_Nicaragua.svg.png 2x" width="23"/> </span><a href="/wiki/Nicaragua" title="Nicaragua">Nicaragua</a><span class="anchor" id="Nicaragua"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Not regulated as of 2014
#  <hr/>
#  <p>As of 2014, the government had not passed any regulation on Bitcoin, nor had the central bank issued rulings or guidelines. In January 2014, <i><a href="/wiki/El_Nuevo_Diario" title="El Nuevo Diario">El Nuevo Diario</a></i> reported that an American banker had used bitcoin to purchase real estate in the country. <sup class="reference" id="cite_ref-regulation_3-1"><a href="#cite_note-regulation-3">[3]</a></sup><sup class="reference nowrap"><span title="Page: Nicaragua">: Nicaragua </span></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Flag_of_Jamaica.svg/23px-Flag_of_Jamaica.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Flag_of_Jamaica.svg/35px-Flag_of_Jamaica.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Flag_of_Jamaica.svg/46px-Flag_of_Jamaica.svg.png 2x" width="23"/> </span><a href="/wiki/Jamaica" title="Jamaica">Jamaica</a><span class="anchor" id="Jamaica"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
#  <p>In 2017, <a class="mw-redirect" href="/wiki/The_Bank_of_Jamaica" title="The Bank of Jamaica">The Bank of Jamaica</a> (BoJ), issued a statement saying that it must create opportunities for the exploitation of cryptocurrency technology.  The BoJ said it planned a campaign to build awareness of cryptocurrencies as part of increasing general financial literacy.<sup class="reference" id="cite_ref-45"><a href="#cite_note-45">[45]</a></sup><sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[46]</a></sup><sup class="reference" id="cite_ref-regulation_3-2"><a href="#cite_note-regulation-3">[3]</a></sup><sup class="reference nowrap"><span title="Page: Jamaica">: Jamaica </span></sup>
#  </p>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="480" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Flag_of_Trinidad_and_Tobago.svg/23px-Flag_of_Trinidad_and_Tobago.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Flag_of_Trinidad_and_Tobago.svg/35px-Flag_of_Trinidad_and_Tobago.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/64/Flag_of_Trinidad_and_Tobago.svg/46px-Flag_of_Trinidad_and_Tobago.svg.png 2x" width="23"/> </span><a href="/wiki/Trinidad_and_Tobago" title="Trinidad and Tobago">Trinidad and Tobago</a><span class="anchor" id="Trinidad_and_Tobago"></span>
#  </td>,
#  <td><a class="image" href="/wiki/File:Yes_check.svg"><img alt="Yes check.svg" data-file-height="600" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/15px-Yes_check.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/23px-Yes_check.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/30px-Yes_check.svg.png 2x" width="15"/></a> Legal
#  <hr/>
# ...
#  <li><a href="/wiki/Marriageable_age" title="Marriageable age">Legal marriage</a> (<a href="/wiki/Marriage_age_in_the_United_States" title="Marriage age in the United States">in the US</a>)</li>
#  <li><a href="/wiki/Retirement_age" title="Retirement age">Retirement age</a>
#  <ul><li><a href="/wiki/Mandatory_retirement" title="Mandatory retirement">Mandatory retirement</a></li></ul></li>
#  <li><a href="/wiki/School-leaving_age" title="School-leaving age">School-leaving age</a></li>
#  <li><a href="/wiki/Smoking_age" title="Smoking age">Legal smoking</a> (<a class="mw-redirect" href="/wiki/Smoking_ages_in_the_United_States" title="Smoking ages in the United States">in the US</a>)</li>
#  <li><a href="/wiki/Voting_age" title="Voting age">Voting</a>
#  <ul><li><a href="/wiki/Suffrage" title="Suffrage">Suffrage</a></li>
#  <li><a href="/wiki/Youth_suffrage" title="Youth suffrage">Youth suffrage</a></li></ul></li>
#  <li><a href="/wiki/Legal_working_age" title="Legal working age">Working age</a></li></ul>
#  </div></td>,
#  <td class="navbox-list-with-group navbox-list navbox-even hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">
#  <ul><li><a href="/wiki/
#  <ul><li><a href="/wiki/List_of_international_rankings" title="List of international rankings">List of international rankings</a></li>
#  <li><a href="/wiki/Lists_by_country" title="Lists by country">Lists by country</a></li></ul>
#  </div></div></td>]

# %%
list1=[]
list2=[]
for td in results3:
    res = td.text
    res1 = res.split('\n')
    list1.append(res1)
    
    for i in list1:
        if len(i) == 1:
            # to remove white space
            l = i[0].lstrip()
            list2.append(l)
        else:
            list2.append(i[0])

fin = list(zip(list2,list2[1:]))[::2]
fin1 = [[w.replace("\xa0", "") for w in words] for words in fin]

# %%
    final_df = pd.DataFrame(fin1, columns=['country', 'value'])
    final_df = final_df[2:].reset_index(drop = True)

# %%
def get_response(wikiurl):
    response=requests.get(wikiurl)
    #print(response.status_code)
    # parse data from the html into a beautifulsoup object
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

def get_table_def(soup):
    list1 = []
    for tr in soup.find_all('table',{'class':"wikitable"}):
        tds = tr.find_all('td')
        for td in tds:
            res = td.text
            res1 = res.split('\n')
            list1.append(res1)
    return list1

def data_prep(list1):
    list2 = []
    for i in list1:
        if len(i) == 1:
            # to remove white space
            l = i[0].lstrip()
            list2.append(l)
        else:
            list2.append(i[0])
    return list2

# %%
soup=get_response(URL5)
list1=get_table_def(soup)
list2=data_prep(list1)

# %%
fin=list(zip(list2,list2[1:]))[::2]

# %%
fin
# Out:
# [('\xa0European Union', ' Legal'),
#  ('G7', ' Legal'),
#  ('\xa0Algeria', ' Illegal'),
#  ('\xa0Egypt', ' Illegal'),
#  ('\xa0Morocco', ' Illegal'),
#  ('\xa0Nigeria', ' Legal /  Banking ban'),
#  ('\xa0Tanzania', ' Legal / Use discouraged by central bank'),
#  ('\xa0Mauritius', ' Legal'),
#  ('\xa0Angola', ' Legal'),
#  ('\xa0South Africa', ' Legal'),
#  ('\xa0Namibia', ' Legal /  Banking ban'),
#  ('\xa0Zimbabwe', ' Unknown'),
#  ('\xa0Canada', ' Legal /  Banking ban'),
#  ('\xa0United States', ' Legal'),
#  ('\xa0Mexico', ' Legal'),
#  ('\xa0Costa Rica', ' Not considered currency'),
#  ('\xa0El Salvador', ' Legal'),
#  ('\xa0Nicaragua', ' Not regulated as of 2014'),
#  ('\xa0Jamaica', ' Legal'),
#  ('\xa0Trinidad and Tobago', ' Legal'),
#  ('\xa0Argentina', ' Legal'),
#  ('\xa0Bolivia', ' Illegal'),
#  ('\xa0Brazil', ' Legal'),
#  ('\xa0Chile', ' Legal'),
#  ('\xa0Colombia', ' Legal /  Banking ban'),
#  ('\xa0Ecuador',
#   ' Legal to trade and hold /  Illegal as a payment tool, banking ban'),
#  ('\xa0Venezuela', ' Legal'),
#  ('\xa0Kyrgyzstan', ' Legal'),
#  ('\xa0Uzbekistan', ' Legal'),
#  ('\xa0United Arab Emirates', ' Legal /  Banking ban'),
#  ('\xa0Israel', ' Legal'),
#  ('\xa0Saudi Arabia', ' Legal /  Banking ban'),
#  ('\xa0Jordan', ' Legal /  Banking ban'),
#  ('\xa0Lebanon', ' Legal'),
#  ('\xa0Turkey', ' Legal /  Banking ban'),
#  ('\xa0Qatar', ' Legal /  Banking ban'),
#  ('\xa0Iran', ' Legal /  Banking ban'),
#  ('\xa0Bangladesh', ' Illegal'),
#  ('\xa0India', ' Legal'),
#  ('\xa0\xa0\xa0Nepal', ' Illegal'),
#  ('\xa0Pakistan', ' Legal'),
#  ('\xa0China (PRC)', ' Illegal'),
#  ('\xa0Hong Kong', ' Legal'),
#  ('\xa0Japan', ' Legal'),
#  ('\xa0South Korea', ' Legal'),
#  ('\xa0Taiwan', ' Legal /  Banking ban'),
#  ('\xa0Cambodia', ' Legal /  Banking ban'),
#  ('\xa0Indonesia', ' Legal to trade and hold /  Illegal as payment tool'),
#  ('\xa0Malaysia', ' Legal'),
#  ('\xa0Philippines', ' Legal'),
#  ('\xa0Singapore', ' Legal'),
#  ('\xa0Thailand', ' Legal to trade and hold /  Illegal as payment tool'),
#  ('\xa0Vietnam', ' Legal to trade and hold /  Illegal as payment tool'),
#  ('\xa0Brunei', ' Legal to trade and hold'),
#  ('\xa0Austria', ' Legal'),
#  ('\xa0Croatia', ' Legal'),
#  ('\xa0Czech Republic', ' Legal'),
#  ('\xa0Germany', ' Legal'),
#  ('\xa0Hungary', ' Legal'),
#  ('\xa0Poland', ' Legal'),
#  ('\xa0Romania', ' Legal'),
#  ('\xa0Slovakia', ' Legal'),
#  ('\xa0Slovenia', ' Legal'),
#  ('\xa0\xa0Switzerland', ' Legal'),
#  ('\xa0Albania', ' Legal'),
#  ('\xa0Belarus', ' Legal'),
#  ('\xa0Georgia', ' Legal'),
#  ('\xa0Kosovo', ' Ban on mining[148]'),
#  ('\xa0Russia', ' Legal to mine  Banking ban'),
#  ('\xa0Ukraine', ' Legal'),
#  ('\xa0Denmark', ' Legal'),
#  ('\xa0Estonia', ' Legal'),
#  ('\xa0Finland', ' Legal'),
#  ('\xa0Iceland', ' Legal'),
#  ('\xa0Lithuania', ' Legal'),
#  ('\xa0Norway', ' Legal'),
#  ('\xa0Sweden', ' Legal'),
#  ('\xa0Bosnia and Herzegovina', ' Legal'),
#  ('\xa0Bulgaria', ' Legal'),
#  ('\xa0Cyprus', ' Legal'),
#  ('\xa0Greece', ' Legal'),
#  ('\xa0Italy', ' Legal'),
#  ('\xa0Malta', ' Legal'),
#  ('\xa0North Macedonia', ' Legal'),
#  ('\xa0Portugal', ' Legal'),
#  ('\xa0Spain', ' Legal'),
#  ('\xa0Belgium', ' Legal'),
#  ('\xa0France', ' Legal'),
#  ('\xa0Ireland', 'Not regulated by central bank'),
#  ('\xa0Luxembourg', ' Legal'),
#  ('\xa0Netherlands', 'Not regulated'),
#  ('\xa0United Kingdom', ' Legal'),
#  ('\xa0Australia', ' Legal'),
#  ('\xa0New Zealand', ' Legal')]

# %%
al'), (['\xa0Kosovo', ''], ' Ban on mining[148]'), (['\xa0Russia', ''], ' Legal to mine  Banking ban'), (['\xa0Ukraine', ''], ' Legal'), (['\xa0Denmark', ''], ' Legal'), (['\xa0Estonia', ''], ' Legal'), (['\xa0Finland', ''], ' Legal'), (['\xa0Iceland', ''], ' Legal'), (['\xa0Lithuania', ''], ' Legal'), (['\xa0Norway', ''], ' Legal'), (['\xa0Sweden', ''], ' Legal'), (['\xa0Bosnia and Herzegovina', ''], ' Legal'), (['\xa0Bulgaria', ''], ' Legal'), (['\xa0Cyprus', ''], ' Legal'), (['\xa0Greece', ''], ' Legal'), (['\xa0Italy', ''], ' Legal'), (['\xa0Malta', ''], ' Legal'), (['\xa0North Macedonia', ''], ' Legal'), (['\xa0Portugal', ''], ' Legal'), (['\xa0Spain', ''], ' Legal'), (['\xa0Belgium', ''], ' Legal'), (['\xa0France', ''], ' Legal'), (['\xa0Ireland', ''], 'Not regulated by central bank'), (['\xa0Luxembourg', ''], ' Legal'), (['\xa0Netherlands', ''], 'Not regulated'), (['\xa0United Kingdom', ''], ' Legal'), (['\xa0Australia', ''], ' Legal'), (['\xa0New Zealand', ''], ' Legal')]

# %%
results3
# Out:
# [(['\xa0European Union', ''], ' Legal'),
#  (['G7', ''], ' Legal'),
#  (['\xa0Algeria', ''], ' Illegal'),
#  (['\xa0Egypt', ''], ' Illegal'),
#  (['\xa0Morocco', ''], ' Illegal'),
#  (['\xa0Nigeria', ''], ' Legal /  Banking ban'),
#  (['\xa0Tanzania', ''], ' Legal / Use discouraged by central bank'),
#  (['\xa0Mauritius', ''], ' Legal'),
#  (['\xa0Angola', ''], ' Legal'),
#  (['\xa0South Africa', ''], ' Legal'),
#  (['\xa0Namibia', ''], ' Legal /  Banking ban'),
#  (['\xa0Zimbabwe', ''], ' Unknown'),
#  (['\xa0Canada', ''], ' Legal /  Banking ban'),
#  (['\xa0United States', ''], ' Legal'),
#  (['\xa0Mexico', ''], ' Legal'),
#  (['\xa0Costa Rica', ''], ' Not considered currency'),
#  (['\xa0El Salvador', ''], ' Legal'),
#  (['\xa0Nicaragua', ''], ' Not regulated as of 2014'),
#  (['\xa0Jamaica', ''], ' Legal'),
#  (['\xa0Trinidad and Tobago', ''], ' Legal'),
#  (['\xa0Argentina', ''], ' Legal'),
#  (['\xa0Bolivia', ''], ' Illegal'),
#  (['\xa0Brazil', ''], ' Legal'),
#  (['\xa0Chile', ''], ' Legal'),
#  (['\xa0Colombia', ''], ' Legal /  Banking ban'),
#  (['\xa0Ecuador', ''],
#   ' Legal to trade and hold /  Illegal as a payment tool, banking ban'),
#  (['\xa0Venezuela', ''], ' Legal'),
#  (['\xa0Kyrgyzstan', ''], ' Legal'),
#  (['\xa0Uzbekistan', ''], ' Legal'),
#  (['\xa0United Arab Emirates', ''], ' Legal /  Banking ban'),
#  (['\xa0Israel', ''], ' Legal'),
#  (['\xa0Saudi Arabia', ''], ' Legal /  Banking ban'),
#  (['\xa0Jordan', ''], ' Legal /  Banking ban'),
#  (['\xa0Lebanon', ''], ' Legal'),
#  (['\xa0Turkey', ''], ' Legal /  Banking ban'),
#  (['\xa0Qatar', ''], ' Legal /  Banking ban'),
#  (['\xa0Iran', ''], ' Legal /  Banking ban'),
#  (['\xa0Bangladesh', ''], ' Illegal'),
#  (['\xa0India', ''], ' Legal'),
#  (['\xa0\xa0\xa0Nepal', ''], ' Illegal'),
#  (['\xa0Pakistan', ''], ' Legal'),
#  (['\xa0China (PRC)', ''], ' Illegal'),
#  (['\xa0Hong Kong', ''], ' Legal'),
#  (['\xa0Japan', ''], ' Legal'),
#  (['\xa0South Korea', ''], ' Legal'),
#  (['\xa0Taiwan', ''], ' Legal /  Banking ban'),
#  (['\xa0Cambodia', ''], ' Legal /  Banking ban'),
#  (['\xa0Indonesia', ''],
#   ' Legal to trade and hold /  Illegal as payment tool'),
#  (['\xa0Malaysia', ''], ' Legal'),
#  (['\xa0Philippines', ''], ' Legal'),
#  (['\xa0Singapore', ''], ' Legal'),
#  (['\xa0Thailand', ''], ' Legal to trade and hold /  Illegal as payment tool'),
#  (['\xa0Vietnam', ''], ' Legal to trade and hold /  Illegal as payment tool'),
#  (['\xa0Brunei', ''], ' Legal to trade and hold'),
#  (['\xa0Austria', ''], ' Legal'),
#  (['\xa0Croatia', ''], ' Legal'),
#  (['\xa0Czech Republic', ''], ' Legal'),
#  (['\xa0Germany', ''], ' Legal'),
#  (['\xa0Hungary', ''], ' Legal'),
#  (['\xa0Poland', ''], ' Legal'),
#  (['\xa0Romania', ''], ' Legal'),
#  (['\xa0Slovakia', ''], ' Legal'),
#  (['\xa0Slovenia', ''], ' Legal'),
#  (['\xa0\xa0Switzerland', ''], ' Legal'),
#  (['\xa0Albania', ''], ' Legal'),
#  (['\xa0Belarus', ''], ' Legal'),
#  (['\xa0Georgia', ''], ' Legal'),
#  (['\xa0Kosovo', ''], ' Ban on mining[148]'),
#  (['\xa0Russia', ''], ' Legal to mine  Banking ban'),
#  (['\xa0Ukraine', ''], ' Legal'),
#  (['\xa0Denmark', ''], ' Legal'),
#  (['\xa0Estonia', ''], ' Legal'),
#  (['\xa0Finland', ''], ' Legal'),
#  (['\xa0Iceland', ''], ' Legal'),
#  (['\xa0Lithuania', ''], ' Legal'),
#  (['\xa0Norway', ''], ' Legal'),
#  (['\xa0Sweden', ''], ' Legal'),
#  (['\xa0Bosnia and Herzegovina', ''], ' Legal'),
#  (['\xa0Bulgaria', ''], ' Legal'),
#  (['\xa0Cyprus', ''], ' Legal'),
#  (['\xa0Greece', ''], ' Legal'),
#  (['\xa0Italy', ''], ' Legal'),
#  (['\xa0Malta', ''], ' Legal'),
#  (['\xa0North Macedonia', ''], ' Legal'),
#  (['\xa0Portugal', ''], ' Legal'),
#  (['\xa0Spain', ''], ' Legal'),
#  (['\xa0Belgium', ''], ' Legal'),
#  (['\xa0France', ''], ' Legal'),
#  (['\xa0Ireland', ''], 'Not regulated by central bank'),
#  (['\xa0Luxembourg', ''], ' Legal'),
#  (['\xa0Netherlands', ''], 'Not regulated'),
#  (['\xa0United Kingdom', ''], ' Legal'),
#  (['\xa0Australia', ''], ' Legal'),
#  (['\xa0New Zealand', ''], ' Legal')]

# %%
pd.DataFrame([[w.replace("\xa0", "") for w in words] for words in results3], columns=['Country', 'Status'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-55d3f440434e> in <module>()
# ----> 1 pd.DataFrame([[w.replace("\xa0", "") for w in words] for words in results3], columns=['Country', 'Status'])
#
# <ipython-input-35-55d3f440434e> in <listcomp>(.0)
# ----> 1 pd.DataFrame([[w.replace("\xa0", "") for w in words] for words in results3], columns=['Country', 'Status'])
#
# <ipython-input-35-55d3f440434e> in <listcomp>(.0)
# ----> 1 pd.DataFrame([[w.replace("\xa0", "") for w in words] for words in results3], columns=['Country', 'Status'])
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
for words in results3:
    print(words)
# Out:
# (['\xa0European Union', ''], ' Legal')
# (['G7', ''], ' Legal')
# (['\xa0Algeria', ''], ' Legal')
# (['\xa0Egypt', ''], ' Legal')
# (['\xa0Morocco', ''], ' Illegal')
# (['\xa0Nigeria', ''], ' Illegal')
# (['\xa0Tanzania', ''], ' Illegal')
# (['\xa0Mauritius', ''], ' Legal')
# (['\xa0Angola', ''], ' Legal')
# (['\xa0South Africa', ''], ' Illegal')
# (['\xa0Namibia', ''], ' Illegal')
# (['\xa0Zimbabwe', ''], ' Illegal')
# (['\xa0Canada', ''], ' Legal /  Banking ban')
# (['\xa0United States', ''], ' Legal')
# (['\xa0Mexico', ''], ' Legal')
# (['\xa0Costa Rica', ''], ' Illegal')
# (['\xa0El Salvador', ''], ' Illegal')
# (['\xa0Nicaragua', ''], ' Illegal')
# (['\xa0Jamaica', ''], ' Legal /  Banking ban')
# (['\xa0Trinidad and Tobago', ''], ' Legal / Use discouraged by central bank')
# (['\xa0Argentina', ''], ' Legal')
# (['\xa0Bolivia', ''], ' Legal')
# (['\xa0Brazil', ''], ' Illegal')
# (['\xa0Chile', ''], ' Illegal')
# (['\xa0Colombia', ''], ' Illegal')
# (['\xa0Ecuador', ''], ' Legal /  Banking ban')
# (['\xa0Venezuela', ''], ' Legal / Use discouraged by central bank')
# (['\xa0Kyrgyzstan', ''], ' Legal')
# (['\xa0Uzbekistan', ''], ' Legal')
# (['\xa0United Arab Emirates', ''], ' Legal')
# (['\xa0Israel', ''], ' Illegal')
# (['\xa0Saudi Arabia', ''], ' Illegal')
# (['\xa0Jordan', ''], ' Illegal')
# (['\xa0Lebanon', ''], ' Legal /  Banking ban')
# (['\xa0Turkey', ''], ' Legal / Use discouraged by central bank')
# (['\xa0Qatar', ''], ' Legal')
# (['\xa0Iran', ''], ' Legal')
# (['\xa0Bangladesh', ''], ' Legal')
# (['\xa0India', ''], ' Legal /  Banking ban')
# (['\xa0\xa0\xa0Nepal', ''], ' Unknown')
# (['\xa0Pakistan', ''], ' Legal')
# (['\xa0China (PRC)', ''], ' Legal')
# (['\xa0Hong Kong', ''], ' Illegal')
# (['\xa0Japan', ''], ' Illegal')
# (['\xa0South Korea', ''], ' Illegal')
# (['\xa0Taiwan', ''], ' Legal /  Banking ban')
# (['\xa0Cambodia', ''], ' Legal / Use discouraged by central bank')
# (['\xa0Indonesia', ''], ' Legal')
# (['\xa0Malaysia', ''], ' Legal')
# (['\xa0Philippines', ''], ' Legal')
# (['\xa0Singapore', ''], ' Legal /  Banking ban')
# (['\xa0Thailand', ''], ' Unknown')
# (['\xa0Vietnam', ''], ' Legal /  Banking ban')
# (['\xa0Brunei', ''], ' Legal')
# (['\xa0Austria', ''], ' Legal')
# (['\xa0Croatia', ''], ' Legal')
# (['\xa0Czech Republic', ''], ' Legal')
# (['\xa0Germany', ''], ' Illegal')
# (['\xa0Hungary', ''], ' Illegal')
# (['\xa0Poland', ''], ' Illegal')
# (['\xa0Romania', ''], ' Legal /  Banking ban')
# (['\xa0Slovakia', ''], ' Legal / Use discouraged by central bank')
# (['\xa0Slovenia', ''], ' Legal')
# (['\xa0\xa0Switzerland', ''], ' Legal')
# (['\xa0Albania', ''], ' Legal')
# (['\xa0Belarus', ''], ' Legal /  Banking ban')
# (['\xa0Georgia', ''], ' Unknown')
# (['\xa0Kosovo', ''], ' Legal /  Banking ban')
# (['\xa0Russia', ''], ' Legal')
# (['\xa0Ukraine', ''], ' Legal')
# (['\xa0Denmark', ''], ' Not considered currency')
# (['\xa0Estonia', ''], ' Legal')
# (['\xa0Finland', ''], ' Not regulated as of 2014')
# (['\xa0Iceland', ''], ' Legal')
# (['\xa0Lithuania', ''], ' Legal')
# (['\xa0Norway', ''], ' Illegal')
# (['\xa0Sweden', ''], ' Illegal')
# (['\xa0Bosnia and Herzegovina', ''], ' Illegal')
# (['\xa0Bulgaria', ''], ' Legal /  Banking ban')
# (['\xa0Cyprus', ''], ' Legal / Use discouraged by central bank')
# (['\xa0Greece', ''], ' Legal')
# (['\xa0Italy', ''], ' Legal')
# (['\xa0Malta', ''], ' Legal')
# (['\xa0North Macedonia', ''], ' Legal /  Banking ban')
# (['\xa0Portugal', ''], ' Unknown')
# (['\xa0Spain', ''], ' Legal /  Banking ban')
# (['\xa0Belgium', ''], ' Legal')
# (['\xa0France', ''], ' Legal')
# (['\xa0Ireland', ''], ' Not considered currency')
# (['\xa0Luxembourg', ''], ' Legal')
# (['\xa0Netherlands', ''], ' Not regulated as of 2014')
# (['\xa0United Kingdom', ''], ' Legal')
# (['\xa0Australia', ''], ' Legal')
# (['\xa0New Zealand', ''], ' Legal')

# %%
import pandas as pd
import requests
import re
import json
from bs4 import BeautifulSoup




def lambda_handler(event=None, context=None):

	headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

	URL1 = "https://www.bitcoinmarketjournal.com/ico-regulations/"
	URL2="https://www.iexpats.com/cryptocurrency-tax-and-rules-by-country/"
	URL3="https://icoda.io/list-of-all-crypto-exchanges/"
	URL4="https://cbdctracker.org/"
	URL5="https://en.wikipedia.org/wiki/Legality_of_cryptocurrency_by_country_or_territory#Detail_by_country_or_territory"
	url="https://cbdctracker.org/api/currencies"

	ptrn=re.compile("(<td>)|(</td>)")
	changes={
	"Yes":"Taxable",
	"No":"Non-Taxable",
	"–":"Banned",
	"Allowed":"Allowed",
	"Allowed, but heavily regulated":"Allowed but regulated",
	"Allowed, but regulated":"Allowed but regulated",
	"Allowed, but subject to future regulations":"Allowed but regulations underway",
	"Allowed, but subject to future regulations":"Allowed but regulations underway",
	"Allowed, but subject to future \xa0 regulations":"Allowed but regulations underway",
	"Allowed/Regulated":"Allowed but regulated",
	"Allowed/See note":"Allowed",
	"Allowed/See Notes":"Allowed",
	"Allowed/Subject to future regulations":"Allowed but regulations underway",
	"Banned":"Banned", 
	"Legal":"Allowed"}

	changes1={"Illegal":"Illegal",
	"Legal /  Banking ban":"Legal but Banking ban",
	"Legal / Use discouraged by central bank":"Legal but use discouraged by central bank",
	"Legal":"Legal",
	"Unknown":"No Data",
	"Not considered currency":"Illegal",
	"Not regulated as of 2014":"Illegal",
	"Legal to trade and hold /  Illegal as a payment tool, banking ban":"Legal but Banking ban",	 
	"Legal to trade and hold /  Illegal as payment tool":"Legal but Banking ban",
	"Legal to trade and hold":"Legal",	 
	"Temporary ban on mining[147]":"Illegal",	 
	"Legal to mine  Banking ban":"Legal but Banking ban",
	"Ban on mining[148]":"Illegal",
	"Not regulated by central bank"	:"Legal but use discouraged by central bank",
	"Not regulated":"Legal but Banking ban"
	}

	i=1
	c=0
	lst=[]
	lst1=[]
	lst2=[]
	lst3=[]
	lst4=[]
	lst5=[]

	print("Scrapping begins.......................")
	def parsing(url,tag,headers,cls_tbl=0):
		page = requests.get(url,verify=False,headers=headers)
		soup = BeautifulSoup(page.content, "html.parser")

		if cls_tbl==0:
			results=soup.find_all(tag)
		else:
			for tr in soup.find_all(cls_tbl[0],{'class':cls_tbl[1]}):
				tds = tr.find_all('td')
				for td in tds:
					lst4.append(td.text.split('\n'))
			for i in lst4:
				if len(i) == 1:
					# to remove white space
					l = i[0].lstrip()
					lst5.append(l)
				else:
					lst5.append(i[0])
			return list(zip(lst5,lst5[1:]))[::2]

		return results



	results=parsing(URL1,"td",headers)
	results1=parsing(URL2,"tr",headers)
	results2=parsing(URL3,"tbody",headers)
	results3=parsing(URL5,"td",headers,['table','wikitable'])


	page = requests.get(url,verify=False,headers=headers)
	data=json.loads(page.content)


	for values in results:
		if ((i%3==0) or (i<3)):
			pass
		else:
			if c==0:
				prev=(values.text)
				c=1
			else:
				lst.append([prev,values.text])
				c=0
		i=i+1


	for values in results1:
		val=values.find_all("td")
		if len(val)!=0:
			lst1.append([re.sub(ptrn,"",str(val[0])),re.sub(ptrn,"",str(val[3]))])

	for values in results2:
		val_p=values.find_all("tr")
		for ind in range(0,len(val_p)):
			dd={}
			for i in val_p[ind]:
				if i.find('span'):
					if i.find("p"):
						dd[i.find("span").text]=i.find("p").text
					else:
						dd[i.find("span").text]=''
				else:
					dd['Exchange']=i.find("p").text
					if i.find("p"):
						dd['Exchange']=i.find("p").text
					else:
						dd['Exchange']=''
					
			lst2.append(dd)

	df_wiki = pd.DataFrame([[w.replace("\xa0", "") for w in words] for words in results3], columns=['Country', 'Status'])

	df_bitcoin=pd.DataFrame(lst,columns=['Country','Status'])
	df_iex=pd.DataFrame(lst1,columns=['Country','Status'])
	df_icod=pd.DataFrame.from_dict(lst2,orient='columns')
	df_cdbc=pd.DataFrame.from_dict(data,orient='columns')

	df_cdbc=df_cdbc[['country','status']]
	df_iex['Status']=df_iex['Status'].apply(lambda x: changes[x])
	df_bitcoin['Status']=df_bitcoin['Status'].apply(lambda x: changes[x])
	df_wiki['Status']=df_wiki['Status'].apply(lambda x: changes1[x.strip()])

	df_icod=df_icod[df_icod['Country']!='No Data']
	df_icod=df_icod[~(df_icod['Launched'].isin(['','No Data']))]

	for con in df_icod['Country'].unique():
		min_val=df_icod[df_icod['Country']==con]['Launched'].min()
		lst3.append([con,df_icod[(df_icod['Country']==con)&(df_icod['Launched']==min_val)]['Type'].values[0]])

	df_icod=pd.DataFrame(lst3,columns=['Country','Status'])


	# df_bitcoin.to_excel("bitcoinmarketjournal.xlsx",index=False)
	# df_iex.to_excel("iexpats.xlsx",index=False)
	# df_icod.to_excel("icoda.xlsx",index=False)
	# df_cdbc.to_excel("cbdctracker.xlsx",index=False)
	# df_wiki.to_excel("wiki.xlsx",index=False)

	print("Websites scrapped Successfully")

	return json.dumps([{'df_wiki':df_wiki.to_dict('records')},
                        {'df_bitcoin':df_bitcoin.to_dict('records')},
                        {'df_iex':df_iex.to_dict('records')},
                        {'df_icod':df_icod.to_dict('records')},
                        {'df_cdbc':df_cdbc.to_dict('records')}])

# %%
import pandas as pd
import requests
import re
import json
from bs4 import BeautifulSoup




def lambda_handler(event=None, context=None):

	headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

	URL1 = "https://www.bitcoinmarketjournal.com/ico-regulations/"
	URL2="https://www.iexpats.com/cryptocurrency-tax-and-rules-by-country/"
	URL3="https://icoda.io/list-of-all-crypto-exchanges/"
	URL4="https://cbdctracker.org/"
	URL5="https://en.wikipedia.org/wiki/Legality_of_cryptocurrency_by_country_or_territory#Detail_by_country_or_territory"
	url="https://cbdctracker.org/api/currencies"

	ptrn=re.compile("(<td>)|(</td>)")
	changes={
	"Yes":"Taxable",
	"No":"Non-Taxable",
	"–":"Banned",
	"Allowed":"Allowed",
	"Allowed, but heavily regulated":"Allowed but regulated",
	"Allowed, but regulated":"Allowed but regulated",
	"Allowed, but subject to future regulations":"Allowed but regulations underway",
	"Allowed, but subject to future regulations":"Allowed but regulations underway",
	"Allowed, but subject to future \xa0 regulations":"Allowed but regulations underway",
	"Allowed/Regulated":"Allowed but regulated",
	"Allowed/See note":"Allowed",
	"Allowed/See Notes":"Allowed",
	"Allowed/Subject to future regulations":"Allowed but regulations underway",
	"Banned":"Banned", 
	"Legal":"Allowed"}

	changes1={"Illegal":"Illegal",
	"Legal /  Banking ban":"Legal but Banking ban",
	"Legal / Use discouraged by central bank":"Legal but use discouraged by central bank",
	"Legal":"Legal",
	"Unknown":"No Data",
	"Not considered currency":"Illegal",
	"Not regulated as of 2014":"Illegal",
	"Legal to trade and hold /  Illegal as a payment tool, banking ban":"Legal but Banking ban",	 
	"Legal to trade and hold /  Illegal as payment tool":"Legal but Banking ban",
	"Legal to trade and hold":"Legal",	 
	"Temporary ban on mining[147]":"Illegal",	 
	"Legal to mine  Banking ban":"Legal but Banking ban",
	"Ban on mining[148]":"Illegal",
	"Not regulated by central bank"	:"Legal but use discouraged by central bank",
	"Not regulated":"Legal but Banking ban"
	}

	i=1
	c=0
	lst=[]
	lst1=[]
	lst2=[]
	lst3=[]
	lst4=[]
	lst5=[]

	print("Scrapping begins.......................")
	def parsing(url,tag,headers,cls_tbl=0):
		page = requests.get(url,verify=False,headers=headers)
		soup = BeautifulSoup(page.content, "html.parser")

		if cls_tbl==0:
			results=soup.find_all(tag)
		else:
			for tr in soup.find_all(cls_tbl[0],{'class':cls_tbl[1]}):
				tds = tr.find_all('td')
				for td in tds:
					lst4.append(td.text.split('\n'))
			for i in lst4:
				if len(i) == 1:
					# to remove white space
					l = i[0].lstrip()
					lst5.append(l)
				else:
					lst5.append(i[0])
			return list(zip(lst5,lst5[1:]))[::2]

		return results



	results=parsing(URL1,"td",headers)
	results1=parsing(URL2,"tr",headers)




	for values in results:
		if ((i%3==0) or (i<3)):
			pass
		else:
			if c==0:
				prev=(values.text)
				c=1
			else:
				lst.append([prev,values.text])
				c=0
		i=i+1


	for values in results1:
		val=values.find_all("td")
		if len(val)!=0:
			lst1.append([re.sub(ptrn,"",str(val[0])),re.sub(ptrn,"",str(val[3]))])



	
	df_bitcoin=pd.DataFrame(lst,columns=['Country','Status'])
	df_iex=pd.DataFrame(lst1,columns=['Country','Status'])


	df_iex['Status']=df_iex['Status'].apply(lambda x: changes[x])
	df_bitcoin['Status']=df_bitcoin['Status'].apply(lambda x: changes[x])




	return json.dumps([
                        {'df_bitcoin':df_bitcoin.to_dict('records')},
                        {'df_iex':df_iex.to_dict('records')}]
                     )

# %%
lambda_handler()
# Out:
# Scrapping begins.......................
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:1050: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.bitcoinmarketjournal.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:1050: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.iexpats.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '[{"df_bitcoin": [{"Country": "European Union", "Status": "Allowed but regulations underway"}, {"Country": "Canada", "Status": "Allowed"}, {"Country": "China", "Status": "Banned"}, {"Country": "Estonia", "Status": "Allowed"}, {"Country": "Germany", "Status": "Allowed"}, {"Country": "Israel", "Status": "Allowed"}, {"Country": "Saudi Arabia", "Status": "Allowed"}, {"Country": "United Arab Emirates", "Status": "Allowed but regulations underway"}, {"Country": "Jordan", "Status": "Allowed but regulated"}, {"Country": "Iran", "Status": "Allowed but regulations underway"}, {"Country": "Lebanon", "Status": "Allowed"}, {"Country": "Turkey", "Status": "Allowed"}, {"Country": "Japan", "Status": "Allowed but regulations underway"}, {"Country": "Bangladesh", "Status": "Banned"}, {"Country": "Nepal", "Status": "Banned"}, {"Country": "Russia", "Status": "Allowed but regulated"}, {"Country": "Singapore", "Status": "Allowed but regulated"}, {"Country": "Cyprus", "Status": "Allowed"}, {"Country": "Kyrgyzstan", "Status": "Allowed"}, {"Country": "Switzerland", "Status": "Allowed but regulations underway"}, {"Country": "Hungary", "Status": "Allowed"}, {"Country": "Croatia", "Status": "Allowed"}, {"Country": "Austria", "Status": "Allowed"}, {"Country": "Czech Republic", "Status": "Allowed"}, {"Country": "Romania", "Status": "Allowed"}, {"Country": "Poland", "Status": "Allowed"}, {"Country": "Slovakia", "Status": "Allowed"}, {"Country": "Slovenia", "Status": "Allowed"}, {"Country": "Belarus", "Status": "Allowed"}, {"Country": "Ukraine", "Status": "Allowed"}, {"Country": "Denmark", "Status": "Allowed"}, {"Country": "Estonia", "Status": "Allowed"}, {"Country": "Finland", "Status": "Allowed"}, {"Country": "Norway", "Status": "Allowed"}, {"Country": "Sweden", "Status": "Allowed but regulations underway"}, {"Country": "Bosnia and Herzegovina", "Status": "Allowed"}, {"Country": "Bulgaria", "Status": "Allowed"}, {"Country": "Greece", "Status": "Allowed"}, {"Country": "Italy", "Status": "Allowed"}, {"Country": "Malta", "Status": "Allowed"}, {"Country": "Macedonia", "Status": "Banned"}, {"Country": "Belgium", "Status": "Allowed"}, {"Country": "France", "Status": "Allowed but regulated"}, {"Country": "Ireland", "Status": "Allowed"}, {"Country": "Luxembourg", "Status": "Allowed but regulated"}, {"Country": "Netherlands", "Status": "Allowed"}, {"Country": "Portugal", "Status": "Allowed"}, {"Country": "Spain", "Status": "Allowed"}, {"Country": "Iceland", "Status": "Allowed"}, {"Country": "Lithuania", "Status": "Allowed"}, {"Country": "United Kingdom", "Status": "Allowed but regulations underway"}, {"Country": "The\\u00a0United States", "Status": "Allowed but regulated"}, {"Country": "Mexico", "Status": "Allowed but regulated"}, {"Country": "Jamaica", "Status": "Allowed"}, {"Country": "Trinidad and Tobago", "Status": "Allowed"}, {"Country": "Nicaragua", "Status": "Allowed"}, {"Country": "Costa Rica", "Status": "Allowed"}, {"Country": "Brazil", "Status": "Allowed"}, {"Country": "Chile", "Status": "Allowed"}, {"Country": "Colombia", "Status": "Allowed"}, {"Country": "Argentina", "Status": "Allowed"}, {"Country": "Bolivia", "Status": "Banned"}, {"Country": "Ecuador", "Status": "Banned"}, {"Country": "Gibraltar (UK)", "Status": "Allowed but regulations underway"}, {"Country": "Isle of Man(UK)", "Status": "Allowed but regulations underway"}, {"Country": "South Korea", "Status": "Allowed"}, {"Country": "Taiwan", "Status": "Allowed"}, {"Country": "Thailand", "Status": "Allowed but regulated"}, {"Country": "Malaysia", "Status": "Allowed but regulations underway"}, {"Country": "Cambodia", "Status": "Allowed"}, {"Country": "Vietnam", "Status": "Allowed"}, {"Country": "Indonesia", "Status": "Allowed"}, {"Country": "India", "Status": "Allowed but regulated"}, {"Country": "Pakistan", "Status": "Banned"}, {"Country": "Hong Kong (China)", "Status": "Allowed but regulations underway"}, {"Country": "Philippines", "Status": "Allowed but regulations underway"}, {"Country": "Algeria ...

# %%
for k,v in {'country':{'s':'georgia'},'status':{'s':'legal'}}.items():
    print(k,list(v.values())[0])
# Out:
# country georgia
# status legal
